# %%
import pandas as pd

# %%
pd.read_excel(r'C:\Users\PC\Desktop\Phython Data Analysis\Python Data Analysis\Academic Success Dataset.xlsx')
# Out:
#     Degree Level   Age  Gender Hours_sleep          Fees  \
# 0             BA  25.0  Female           6  Your parents
# 1            MBA  23.0  Female           6           You
# 2             BA  21.0  Female           5           You
# 3             BA  19.0  Female           6           You
# 4             BA  20.0  Female           6  Your parents
# ..           ...   ...     ...         ...           ...
# 97           NaN   NaN     NaN         NaN           NaN
# 98           NaN   NaN     NaN         NaN           NaN
# 99           NaN   NaN     NaN         NaN           NaN
# 100          NaN   NaN     NaN         NaN           NaN
# 101          NaN   NaN     NaN         Age           NaN
#
#     Extracurricular activities Bac_type  Bac_grade   GPA English_level  ...  \
# 0                       Rarely       SV       12.0  3.23     Excellent  ...
# 1                       Rarely       SE       13.0  2.40          Fair  ...
# ...

# %%
vd=pd.read_excel(r'C:\Users\PC\Desktop\Phython Data Analysis\Python Data Analysis\Academic Success Dataset.xlsx')

# %%
vd
# Out:
#     Degree Level   Age  Gender Hours_sleep          Fees  \
# 0             BA  25.0  Female           6  Your parents
# 1            MBA  23.0  Female           6           You
# 2             BA  21.0  Female           5           You
# 3             BA  19.0  Female           6           You
# 4             BA  20.0  Female           6  Your parents
# ..           ...   ...     ...         ...           ...
# 97           NaN   NaN     NaN         NaN           NaN
# 98           NaN   NaN     NaN         NaN           NaN
# 99           NaN   NaN     NaN         NaN           NaN
# 100          NaN   NaN     NaN         NaN           NaN
# 101          NaN   NaN     NaN         Age           NaN
#
#     Extracurricular activities Bac_type  Bac_grade   GPA English_level  ...  \
# 0                       Rarely       SV       12.0  3.23     Excellent  ...
# 1                       Rarely       SE       13.0  2.40          Fair  ...
# ...

# %%
vd.head()
# Out:
#   Degree Level   Age  Gender Hours_sleep          Fees  \
# 0           BA  25.0  Female           6  Your parents
# 1          MBA  23.0  Female           6           You
# 2           BA  21.0  Female           5           You
# 3           BA  19.0  Female           6           You
# 4           BA  20.0  Female           6  Your parents
#
#   Extracurricular activities Bac_type  Bac_grade   GPA English_level  ...  \
# 0                     Rarely       SV       12.0  3.23     Excellent  ...
# 1                     Rarely       SE       13.0  2.40          Fair  ...
# 2                     Rarely       SE       18.0  4.00     Excellent  ...
# 3                     Rarely       SE       12.7  2.70          Poor  ...
# 4                 Frequently       SE       14.0  3.40     Excellent  ...
#
#    Work_study_related Higher_Diploma    SUM    sum2   Average   MAX  MIN  IF  \
# 0                 NaN            Yes  28.23  292.15  3.043229  60.0  0.0 NaN
# ...

# %%
vd['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as pl

# %%
 #   plt.bar(x,y)
plt.barh(x,y)
plt.scatter(x,y)
plt.pie(x)
plt.hist(x)
plt.area(x,y)
plt.boxplot(x,y)

# %%
vd.head(2)
# Out:
#   Degree Level   Age  Gender Hours_sleep          Fees  \
# 0           BA  25.0  Female           6  Your parents
# 1          MBA  23.0  Female           6           You
#
#   Extracurricular activities Bac_type  Bac_grade   GPA English_level  ...  \
# 0                     Rarely       SV       12.0  3.23     Excellent  ...
# 1                     Rarely       SE       13.0  2.40          Fair  ...
#
#    Work_study_related Higher_Diploma    SUM    sum2   Average   MAX  MIN  IF  \
# 0                 NaN            Yes  28.23  292.15  3.043229  60.0  0.0 NaN
# 1                  No             No  25.40  292.15  3.043229  60.0  0.0 NaN
#
#    LEN  CONCATE
# 0  5.0      NaN
# 1  4.0      NaN
#
# [2 rows x 24 columns]

# %%
x=vd['GPA']
y=vd['Age']

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 102 artists>

# %%
plt.figure(figsize=(8,5))
plt.bar(x,y)
# Out:
# <BarContainer object of 102 artists>

# %%
plt.figure(figsize=(8,5))
plt.bar(x,y)
plt.xlabel('Age',size=12)
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.figure(figsize=(8,5))
plt.bar(x,y)
plt.xlabel('Age',size=12,color='blue')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.figure(figsize=(8,5))
plt.bar(x,y)
plt.xlabel('Age',size=12,color='blue')
plt.ylabel('GPA',size=14,color='blue')
# Out:
# Text(0, 0.5, 'GPA')

# %%
plt.figure(figsize=(8,5))
plt.bar(x,y)
plt.xlabel('Age',size=12,color='blue')
plt.ylabel('GPA',size=14,color='blue')
plt.title('ACADEMIC DATASET',size=20)
# Out:
# Text(0.5, 1.0, 'ACADEMIC DATASET')

# %%
plt.figure(figsize=(8,5))
plt.bar(x,y)
plt.xlabel('Age',size=12,color='blue')
plt.ylabel('GPA',size=14,color='blue')
plt.title('ACADEMIC DATASET',size=20)
plt.grid()

# %%
plt.figure(figsize=(8,5))
plt.bar(x,y)
plt.xlabel('Age',size=12,color='blue')
plt.ylabel('GPA',size=14,color='blue')
plt.title('ACADEMIC DATASET',size=20)
plt.grid()
plt.legend(loc='best')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(8,5))
plt.bar(x,y)
plt.xlabel('Age',size=12,color='blue')
plt.ylabel('GPA',size=14,color='blue')
plt.title('ACADEMIC DATASET',size=20)
plt.grid()
plt.legend(loc='best')
plt.xticks(color='blue',rotation=90)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (array([0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  [Text(0.5, 0, '0.5'),
#   Text(1.0, 0, '1.0'),
#   Text(1.5, 0, '1.5'),
#   Text(2.0, 0, '2.0'),
#   Text(2.5, 0, '2.5'),
#   Text(3.0, 0, '3.0'),
#   Text(3.5, 0, '3.5'),
#   Text(4.0, 0, '4.0'),
#   Text(4.5, 0, '4.5'),
#   Text(5.0, 0, '5.0')])

# %%
plt.figure(figsize=(8,5))
plt.bar(x,y)
plt.xlabel('Age',size=12,color='blue')
plt.ylabel('GPA',size=14,color='blue')
plt.title('ACADEMIC DATASET',size=20)
plt.grid()
plt.legend(loc='best')
plt.xticks(color='blue',rotation=90)
plt.yticks(color='y')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 5.0, '5'),
#   Text(0, 10.0, '10'),
#   Text(0, 15.0, '15'),
#   Text(0, 20.0, '20'),
#   Text(0, 25.0, '25'),
#   Text(0, 30.0, '30'),
#   Text(0, 35.0, '35')])

# %%
plt.figure(figsize=(8,5))
plt.bar(x,y,color='red',label=2023)
plt.xlabel('Age',size=12,color='blue')
plt.ylabel('GPA',size=14,color='blue')
plt.title('ACADEMIC DATASET',size=20)
plt.grid()
plt.legend(loc='best')
plt.xticks(color='blue',rotation=90)
plt.yticks(color='y');

# %% [markdown]
# ### Horizontal bar plot

# %%
plt.figure(figsize=(8,5))
plt.barh(x,y,color='red',label=2023)
plt.xlabel('Age',size=12,color='blue')
plt.ylabel('GPA',size=14,color='blue')
plt.title('ACADEMIC DATASET',size=20)
plt.grid()
plt.legend(loc='best')
plt.xticks(color='blue',rotation=90)
plt.yticks(color='y');
