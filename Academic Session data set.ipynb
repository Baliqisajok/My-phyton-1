# %%
import pandas as pd

# %%
pd.read_excel(r'C:\Users\PC\Desktop\Phython Data Analysis\Python Data Analysis\Academic Success Dataset.xlsx')
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pd.read_excel('C:\\Users\\PC\\Desktop\\Phython Data Analysis\\Python Data Analysis\\Academic Success Dataset.xlsx')
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt=pd.read_excel('C:\\Users\\PC\\Desktop\\Phython Data Analysis\\Python Data Analysis\\Academic Success Dataset.xlsx')

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt.head()
# Out:
#   Degree Level  Age  Gender Hours_sleep          Fees  \
# 0           BA   25  Female           6  Your parents
# 1          MBA   23  Female           6           You
# 2           BA   21  Female           5           You
# 3           BA   19  Female           6           You
# 4           BA   20  Female           6  Your parents
#
#   Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                     Rarely       SV       12.0  3.23     Excellent
# 1                     Rarely       SE       13.0  2.40          Fair
# 2                     Rarely       SE       18.0  4.00     Excellent
# 3                     Rarely       SE       12.7  2.70          Poor
# 4                 Frequently       SE       14.0  3.40     Excellent
#
#    Attendance          Study       Work  Working hours per week  \
# 0         1.0  Prior to exam         No                     0.0
# 1         0.4  Prior to exam  Full time                    45.0
# ...

# %%
pt.tail()
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 91                     Rarely       SE       11.0  3.30     Excellent
# 92                     Rarely       BT       11.0  2.40     Excellent
# 93                     Rarely       SE       12.0  2.50     Excellent
# 94                 Frequently       SE       11.0  2.37     Excellent
# 95                 Frequently       SV       11.0  2.80     Excellent
#
#     Attendance          Study       Work  Working hours per week  \
# 91         0.7  Prior to exam  Full time                    45.0
# 92         0.4  Prior to exam  Full time                    35.0
# ...

# %%
pt.shape
# Out:
# (96, 19)

# %%
pt['Age'].mean()
# Out:
# 24.520833333333332

# %%
pt.dtypes
# Out:
# Degree Level                   object
# Age                             int64
# Gender                         object
# Hours_sleep                    object
# Fees                           object
# Extracurricular activities     object
# Bac_type                       object
# Bac_grade                     float64
# GPA                           float64
# English_level                  object
# Attendance                    float64
# Study                          object
# Work                           object
# Working hours per week        float64
# Work_study_related             object
# Higher_Diploma                 object
# SUM                           float64
# sum2                          float64
# Average                       float64
# dtype: object

# %%
pt.describe()
# Out:
#              Age  Bac_grade        GPA  Attendance  Working hours per week  \
# count  96.000000  96.000000  96.000000   96.000000               96.000000
# mean   24.520833  12.263750   3.043229    0.795312               38.671875
# std     3.118634   1.598609   0.525099    0.170151               14.265126
# min    18.000000  10.000000   1.500000    0.300000                0.000000
# 25%    22.000000  11.000000   2.700000    0.700000               30.000000
# 50%    24.500000  12.000000   3.000000    0.850000               40.000000
# 75%    27.000000  13.000000   3.400000    0.900000               48.000000
# max    32.000000  18.000000   4.000000    1.000000               60.000000
#
#              SUM          sum2       Average
# count  96.000000  9.600000e+01  9.600000e+01
# mean   27.564063  2.921500e+02  3.043229e+00
# std     3.162893  5.142763e-13  2.678522e-15
# min    21.700000  2.921500e+02  3.043229e+00
# 25%    25.175000  2.921500e+02  3.043229e+00
# ...

# %%
pt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Degree Level                96 non-null     object
#  1   Age                         96 non-null     int64
#  2   Gender                      96 non-null     object
#  3   Hours_sleep                 96 non-null     object
#  4   Fees                        96 non-null     object
#  5   Extracurricular activities  96 non-null     object
#  6   Bac_type                    96 non-null     object
#  7   Bac_grade                   96 non-null     float64
#  8   GPA                         96 non-null     float64
#  9   English_level               96 non-null     object
#  10  Attendance                  96 non-null     float64
#  11  Study                       96 non-null     object
#  12  Work                        96 non-null     object
# ...

# %%
round(pt['Age'].mean())
# Out:
# 25

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %% [markdown]
# ## Compare the average working hours per week of the females and the males in the data.

# %%
pt[['Gender','Working hours per week']].groupby('Gender').mean().round()
# Out:
#         Working hours per week
# Gender
# Female                    38.0
# Male                      40.0

# %%
round(pt['Working hours per week'].mean())
# Out:
# 39

# %%
pt[['Gender','Extracurricular activities']]
# Out:
#     Gender Extracurricular activities
# 0   Female                     Rarely
# 1   Female                     Rarely
# 2   Female                     Rarely
# 3   Female                     Rarely
# 4   Female                 Frequently
# ..     ...                        ...
# 91    Male                     Rarely
# 92    Male                     Rarely
# 93  Female                     Rarely
# 94    Male                 Frequently
# 95    Male                 Frequently
#
# [96 rows x 2 columns]

# %% [markdown]
# ## Plot a bar chart showing the distribution of student’sinvolvements in extracurricular activities

# %%
pt['Extracurricular activities'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
pt['Extracurricular activities'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Extracurricular activities'>

# %% [markdown]
# ### Compare the average GPA of students that study FREQUENTLY and students that only study
# PRIOR TO EXAM

# %%
pt[['Study','GPA']].style.highlight_between(subset='GPA',left=pt['GPA'].mean())
# Out:
# <style type="text/css">
# #T_e0da3_row0_col1, #T_e0da3_row2_col1, #T_e0da3_row4_col1, #T_e0da3_row5_col1, #T_e0da3_row6_col1, #T_e0da3_row7_col1, #T_e0da3_row11_col1, #T_e0da3_row15_col1, #T_e0da3_row17_col1, #T_e0da3_row20_col1, #T_e0da3_row21_col1, #T_e0da3_row22_col1, #T_e0da3_row24_col1, #T_e0da3_row25_col1, #T_e0da3_row29_col1, #T_e0da3_row30_col1, #T_e0da3_row31_col1, #T_e0da3_row32_col1, #T_e0da3_row33_col1, #T_e0da3_row34_col1, #T_e0da3_row35_col1, #T_e0da3_row36_col1, #T_e0da3_row37_col1, #T_e0da3_row40_col1, #T_e0da3_row42_col1, #T_e0da3_row45_col1, #T_e0da3_row46_col1, #T_e0da3_row47_col1, #T_e0da3_row49_col1, #T_e0da3_row51_col1, #T_e0da3_row54_col1, #T_e0da3_row56_col1, #T_e0da3_row61_col1, #T_e0da3_row63_col1, #T_e0da3_row64_col1, #T_e0da3_row65_col1, #T_e0da3_row76_col1, #T_e0da3_row77_col1, #T_e0da3_row81_col1, #T_e0da3_row82_col1, #T_e0da3_row85_col1, #T_e0da3_row86_col1, #T_e0da3_row91_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_e0da3">
# ...

# %%
pt[['Study','GPA']].groupby('Study').mean()
# Out:
#                     GPA
# Study
# Frequently     3.160769
# Prior to exam  2.999571

# %%
pt['GPA'].mean()
# Out:
# 3.0432291666666664

# %%
round(pt['GPA'].mean())
# Out:
# 3

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt.query("Study=='Prior to exam'")
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 5            BA   21    Male           4           You
# ..          ...  ...     ...         ...           ...
# 90           BA   29    Male           6           You
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt.query("Study=='Frequently'")
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 4            BA   20  Female           6  Your parents
# 9           MBA   23  Female           8           You
# 10          MBA   21  Female           6           You
# 13           BA   26    Male           8           You
# 17           BA   20  Female           8           You
# 18           BA   23    Male           7           You
# 29           BA   32  Female         5.5           You
# 30           BA   26  Female           7  Your parents
# 35          MBA   26    Male           8           You
# 37          MBA   27    Male           6           You
# 39           BA   27    Male           7  Your parents
# 40          MBA   29    Male           7           You
# 41           BA   27    Male          7#  Your parents
# 42          MBA   23  Female           7           You
# 48           BA   28    Male           7           You
# 50          MBA   26    Male           6           You
# ...

# %%
pt.query("Study=='Prior to exam'").mean()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9052\3457282400.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pt.query("Study=='Prior to exam'").mean()
# Age                        24.442857
# Bac_grade                  12.290286
# GPA                         2.999571
# Attendance                  0.766429
# Working hours per week     40.035714
# SUM                        27.442429
# sum2                      292.150000
# Average                     3.043229
# dtype: float64

# %%
pt.query("Study=='Frequently'").mean()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9052\3406778056.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pt.query("Study=='Frequently'").mean()
# Age                        24.730769
# Bac_grade                  12.192308
# GPA                         3.160769
# Attendance                  0.873077
# Working hours per week     35.000000
# SUM                        27.891538
# sum2                      292.150000
# Average                     3.043229
# dtype: float64

# %%
pt.query("Age=='Frequently'").mean()
# Out:
# Degree Level                  NaN
# Age                           NaN
# Gender                        NaN
# Hours_sleep                   NaN
# Fees                          NaN
# Extracurricular activities    NaN
# Bac_type                      NaN
# Bac_grade                     NaN
# GPA                           NaN
# English_level                 NaN
# Attendance                    NaN
# Study                         NaN
# Work                          NaN
# Working hours per week        NaN
# Work_study_related            NaN
# Higher_Diploma                NaN
# SUM                           NaN
# sum2                          NaN
# Average                       NaN
# dtype: object

# %%
pt.query("Age=='Prior to exam'").mean()
# Out:
# Degree Level                  NaN
# Age                           NaN
# Gender                        NaN
# Hours_sleep                   NaN
# Fees                          NaN
# Extracurricular activities    NaN
# Bac_type                      NaN
# Bac_grade                     NaN
# GPA                           NaN
# English_level                 NaN
# Attendance                    NaN
# Study                         NaN
# Work                          NaN
# Working hours per week        NaN
# Work_study_related            NaN
# Higher_Diploma                NaN
# SUM                           NaN
# sum2                          NaN
# Average                       NaN
# dtype: object

# %%
pt.query("Study=='Frequently'")['Age'].mean()
# Out:
# 24.73076923076923

# %%
pt.query("Study=='Prior to exam'")['Age'].mean()
# Out:
# 24.442857142857143

# %% [markdown]
# ## Plot a bar chart showing the gender distribution in the dataset

# %%
pt['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ## Find the max GPA attained by a female in this dataset

# %%
pt.query("Gender=='Female'")['GPA'].max()
# Out:
# 4.0

# %% [markdown]
# ## Find out if the female with the highest GPA is employed or not

# %%
pt.query('Gender=="Female"').sort_values(by='GPA',ascending=False)
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 2            BA   21  Female           5           You
# 33           BA   25  Female           7           You
# 65           BA   22  Female           7           You
# 76           BA   23  Female           6           You
# 20           BA   22  Female           5           You
# 36          MBA   23  Female           6           You
# 30           BA   26  Female           7  Your parents
# 64           BA   23  Female           8           You
# 11           BA   21  Female           8  Your parents
# 25          MBA   25  Female           7  Your parents
# 47           BA   24  Female           7           You
# 63           BA   22  Female           6           You
# 22          MBA   21  Female           7  Your parents
# 4            BA   20  Female           6  Your parents
# 21           BA   20  Female           5           You
# 17           BA   20  Female           8           You
# ...

# %%
pt.query('Gender=="Female"').sort_values(by='GPA',ascending=False).loc[2]
# Out:
# Degree Level                             BA
# Age                                      21
# Gender                               Female
# Hours_sleep                               5
# Fees                                    You
# Extracurricular activities           Rarely
# Bac_type                                 SE
# Bac_grade                              18.0
# GPA                                     4.0
# English_level                     Excellent
# Attendance                              1.0
# Study                         Prior to exam
# Work                              Part Time
# Working hours per week                 25.0
# Work_study_related                      Yes
# Higher_Diploma                          Yes
# SUM                                    25.0
# sum2                                 292.15
# Average                            3.043229
# Name: 2, dtype: object

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt['Age'].sum()
# Out:
# 2354

# %%
pt['Working hours per week'].sum()
# Out:
# 3712.5

# %%
pt['Working hours per week'].mean()
# Out:
# 38.671875

# %%
pt['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
pt['Gender'].value_counts()
# Out:
# Female    49
# Male      47
# Name: Gender, dtype: int64

# %% [markdown]
# ### The Bookworms are those students who RARELY engage in EXTRACURRICULAR ACTIVITIES
# and STUDY Frequently, how many bookworms are there in the data?

# %%
pt['Extracurricular activities'].value_counts()
# Out:
# Rarely        55
# Frequently    37
# Never          4
# Name: Extracurricular activities, dtype: int64

# %%
pt[pt['Extracurricular activities']=='Rarely']
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 6            BA   18    Male           9           You
# 7            BA   21  Female           6           You
# 8            BA   20  Female           5           You
# 10          MBA   21  Female           6           You
# 11           BA   21  Female           8  Your parents
# 12           BA   23    Male           9           You
# 16           BA   20  Female           6           You
# 18           BA   23    Male           7           You
# 20           BA   22  Female           5           You
# 21           BA   20  Female           5           You
# 24          MBA   25  Female           6  Your parents
# 31          MBA   31    Male           9           You
# ...

# %%
pt['Extracurricular activities'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
pt['Extracurricular activities'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Extracurricular activities'>

# %%
pt.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of     Degree Level    Age  Gender  Hours_sleep   Fees  \
# 0          False  False   False        False  False
# 1          False  False   False        False  False
# 2          False  False   False        False  False
# 3          False  False   False        False  False
# 4          False  False   False        False  False
# ..           ...    ...     ...          ...    ...
# 91         False  False   False        False  False
# 92         False  False   False        False  False
# 93         False  False   False        False  False
# 94         False  False   False        False  False
# 95         False  False   False        False  False
#
#     Extracurricular activities  Bac_type  Bac_grade    GPA  English_level  \
# 0                        False     False      False  False          False
# 1                        False     False      False  False          False
# ...

# %%
pt.isnull()
# Out:
#     Degree Level    Age  Gender  Hours_sleep   Fees  \
# 0          False  False   False        False  False
# 1          False  False   False        False  False
# 2          False  False   False        False  False
# 3          False  False   False        False  False
# 4          False  False   False        False  False
# ..           ...    ...     ...          ...    ...
# 91         False  False   False        False  False
# 92         False  False   False        False  False
# 93         False  False   False        False  False
# 94         False  False   False        False  False
# 95         False  False   False        False  False
#
#     Extracurricular activities  Bac_type  Bac_grade    GPA  English_level  \
# 0                        False     False      False  False          False
# 1                        False     False      False  False          False
# 2                        False     False      False  False          False
# ...

# %% [markdown]
# ## The groupby method

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt.groupby('Gender').sum()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9052\2583062626.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pt.groupby('Gender').sum()
#          Age  Bac_grade     GPA  Attendance  Working hours per week      SUM  \
# Gender
# Female  1156     613.57  149.63       39.65                  1848.0  1305.63
# Male    1198     563.75  142.52       36.70                  1864.5  1340.52
#
#             sum2     Average
# Gender
# Female  14315.35  149.118229
# Male    13731.05  143.031771

# %%
pt.groupby('English_level').sum()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9052\1849830895.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pt.groupby('English_level').sum()
#                 Age  Bac_grade     GPA  Attendance  Working hours per week  \
# English_level
# Excellent      1349     673.37  170.16       44.10                  2128.0
# Fair            986     491.25  119.29       31.65                  1536.5
# Poor             19      12.70    2.70        0.60                    48.0
#
#                    SUM      sum2     Average
# English_level
# Excellent      1519.16  15776.10  164.334375
# Fair           1105.29  11978.15  124.772396
# Poor             21.70    292.15    3.043229

# %%
pt.groupby('Gender').sum().mean()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9052\3496792105.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pt.groupby('Gender').sum().mean()
# Age                        1177.000
# Bac_grade                   588.660
# GPA                         146.075
# Attendance                   38.175
# Working hours per week     1856.250
# SUM                        1323.075
# sum2                      14023.200
# Average                     146.075
# dtype: float64

# %%
pt.groupby('Gender').mean()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9052\931594610.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pt.groupby('Gender').mean()
#               Age  Bac_grade       GPA  Attendance  Working hours per week  \
# Gender
# Female  23.591837  12.521837  3.053673    0.809184               37.714286
# Male    25.489362  11.994681  3.032340    0.780851               39.670213
#
#               SUM    sum2   Average
# Gender
# Female  26.645510  292.15  3.043229
# Male    28.521702  292.15  3.043229

# %%
pt.query('Gender=="Female"')['Age'].mean()
# Out:
# 23.591836734693878

# %%
pt.query('Gender=="Male"')['Age'].mean()
# Out:
# 25.48936170212766

# %%
pt['GPA'].sum()
# Out:
# 292.15

# %%
pt[['Gender','GPA']].groupby('Gender').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
pt[['Gender','GPA']].groupby('Gender').mean()
# Out:
#              GPA
# Gender
# Female  3.053673
# Male    3.032340

# %%
pt.head(4)
# Out:
#   Degree Level  Age  Gender Hours_sleep          Fees  \
# 0           BA   25  Female           6  Your parents
# 1          MBA   23  Female           6           You
# 2           BA   21  Female           5           You
# 3           BA   19  Female           6           You
#
#   Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                     Rarely       SV       12.0  3.23     Excellent
# 1                     Rarely       SE       13.0  2.40          Fair
# 2                     Rarely       SE       18.0  4.00     Excellent
# 3                     Rarely       SE       12.7  2.70          Poor
#
#    Attendance          Study       Work  Working hours per week  \
# 0         1.0  Prior to exam         No                     0.0
# 1         0.4  Prior to exam  Full time                    45.0
# 2         1.0  Prior to exam  Part Time                    25.0
# 3         0.6  Prior to exam  Full time                    48.0
#
# ...

# %%
pt[['Gender','Bac_type','GPA']].groupby(['Gender','GPA']).sum()
# Out:
#                        Bac_type
# Gender GPA
# Female 1.50                  SE
#        1.85                SESE
#        2.20                  SE
#        2.40                  SE
#        2.50            SVSESESE
#        2.60                  SE
#        2.70            SESEBTSE
#        2.80                  SV
#        2.85                  BT
#        2.90                SESE
#        3.00          SVLHLHBTSE
#        3.10                  SE
#        3.20            SESESESE
#        3.21                  SE
#        3.23                  SV
#        3.25                  SV
#        3.30            SESESVSV
#        3.40              SESESE
#        3.45                  SV
#        3.50                SESE
#        3.60                  BT
#        3.68                  SE
#        3.80                SESE
#        3.81                  SV
#        3.92                  SV
#        3.93                  SV
#        4.00                  SE
# Male   2.10                  BT
# ...

# %%
pt.groupby('GPA').count()
# Out:
#       Degree Level  Age  Gender  Hours_sleep  Fees  \
# GPA
# 1.50             1    1       1            1     1
# 1.85             2    2       2            2     2
# 2.10             1    1       1            1     1
# 2.18             1    1       1            1     1
# 2.20             2    2       2            2     2
# 2.37             1    1       1            1     1
# 2.40             2    2       2            2     2
# 2.44             1    1       1            1     1
# 2.50             5    5       5            5     5
# 2.60             3    3       3            3     3
# 2.70             8    8       8            8     8
# 2.80             8    8       8            8     8
# 2.85             1    1       1            1     1
# 2.90             3    3       3            3     3
# 3.00            14   14      14           14    14
# 3.10             2    2       2            2     2
# 3.20             5    5       5            5     5
# ...

# %%
pt[['Gender','Age']].groupby('Gender').mean()
# Out:
#               Age
# Gender
# Female  23.591837
# Male    25.489362

# %% [markdown]
# ## Sorting values

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt.sort_values("Age").head()
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 6            BA   18    Male           9           You
# 87           BA   19    Male         //6           You
# 3            BA   19  Female           6           You
# 23           BA   19    Male           9  Your parents
# 21           BA   20  Female           5           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 6                      Rarely       SE       11.0  3.75          Fair
# 87                 Frequently       BT       13.0  2.80     Excellent
# 3                      Rarely       SE       12.7  2.70          Poor
# 23                 Frequently       SV       11.5  3.00          Fair
# 21                     Rarely       SE       13.0  3.30     Excellent
#
#     Attendance          Study       Work  Working hours per week  \
# 6          0.9  Prior to exam  Part Time                    23.0
# 87         0.7  Prior to exam  Full time                    45.0
# ...

# %%
pt.sort_values(by="Age",ascending=False).head()  #from the last number below
# Out:
#    Degree Level  Age  Gender Hours_sleep Fees Extracurricular activities  \
# 29           BA   32  Female         5.5  You                 Frequently
# 43          MBA   31  Female           8  You                     Rarely
# 15           BA   31    Male           8  You                 Frequently
# 31          MBA   31    Male           9  You                     Rarely
# 44          MBA   31  Female           8  You                     Rarely
#
#    Bac_type  Bac_grade   GPA English_level  Attendance          Study  \
# 29       SE       14.0  3.20     Excellent         1.0     Frequently
# 43       LH       12.0  3.00     Excellent         0.9  Prior to exam
# 15       SG       13.0  3.90     Excellent         0.9  Prior to exam
# 31       BT       15.0  3.28          Fair         0.8  Prior to exam
# 44       LH       12.0  3.00     Excellent         0.9  Prior to exam
#
#          Work  Working hours per week Work_study_related Higher_Diploma  \
# ...

# %%
pt.sort_values(by="Age",ascending=True).head() #from the lowest number downward
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 6            BA   18    Male           9           You
# 87           BA   19    Male         //6           You
# 3            BA   19  Female           6           You
# 23           BA   19    Male           9  Your parents
# 21           BA   20  Female           5           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 6                      Rarely       SE       11.0  3.75          Fair
# 87                 Frequently       BT       13.0  2.80     Excellent
# 3                      Rarely       SE       12.7  2.70          Poor
# 23                 Frequently       SV       11.5  3.00          Fair
# 21                     Rarely       SE       13.0  3.30     Excellent
#
#     Attendance          Study       Work  Working hours per week  \
# 6          0.9  Prior to exam  Part Time                    23.0
# 87         0.7  Prior to exam  Full time                    45.0
# ...

# %%
pt.sort_values(by="Age",ascending=True)
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 6            BA   18    Male           9           You
# 87           BA   19    Male         //6           You
# 3            BA   19  Female           6           You
# 23           BA   19    Male           9  Your parents
# 21           BA   20  Female           5           You
# ..          ...  ...     ...         ...           ...
# 43          MBA   31  Female           8           You
# 31          MBA   31    Male           9           You
# 15           BA   31    Male           8           You
# 44          MBA   31  Female           8           You
# 29           BA   32  Female         5.5           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 6                      Rarely       SE       11.0  3.75          Fair
# 87                 Frequently       BT       13.0  2.80     Excellent
# 3                      Rarely       SE       12.7  2.70          Poor
# ...

# %%
pt.sort_values(by="Age",ascending=False)
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 29           BA   32  Female         5.5           You
# 43          MBA   31  Female           8           You
# 15           BA   31    Male           8           You
# 31          MBA   31    Male           9           You
# 44          MBA   31  Female           8           You
# ..          ...  ...     ...         ...           ...
# 17           BA   20  Female           8           You
# 87           BA   19    Male         //6           You
# 3            BA   19  Female           6           You
# 23           BA   19    Male           9  Your parents
# 6            BA   18    Male           9           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 29                 Frequently       SE       14.0  3.20     Excellent
# 43                     Rarely       LH       12.0  3.00     Excellent
# 15                 Frequently       SG       13.0  3.90     Excellent
# ...

# %%
pt.sort_values('Study').head
# Out:
# <bound method NDFrame.head of    Degree Level  Age  Gender Hours_sleep          Fees  \
# 56          MBA   27    Male           6           You
# 71           BA   25    Male           5  Your parents
# 30           BA   26  Female           7  Your parents
# 29           BA   32  Female         5.5           You
# 37          MBA   27    Male           6           You
# ..          ...  ...     ...         ...           ...
# 28           BA   27  Female           7  Your parents
# 27           BA   30    Male           7           You
# 26          MBA   27  Female           7  Your parents
# 36          MBA   23  Female           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 56                     Rarely       SV       10.5  3.50     Excellent
# 71                     Rarely       SE       11.0  2.70          Fair
# ...

# %%
pt.sort_values('Study').head()
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 56          MBA   27    Male           6           You
# 71           BA   25    Male           5  Your parents
# 30           BA   26  Female           7  Your parents
# 29           BA   32  Female         5.5           You
# 37          MBA   27    Male           6           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 56                     Rarely       SV       10.5  3.50     Excellent
# 71                     Rarely       SE       11.0  2.70          Fair
# 30                 Frequently       SE       13.0  3.68     Excellent
# 29                 Frequently       SE       14.0  3.20     Excellent
# 37                     Rarely       SE       11.0  3.30     Excellent
#
#     Attendance       Study       Work  Working hours per week  \
# 56         0.9  Frequently  Full time                    48.0
# 71         0.9  Frequently  Full time                    40.0
# ...

# %%
pt.sort_values(by="Study",ascending=True).head()
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 56          MBA   27    Male           6           You
# 71           BA   25    Male           5  Your parents
# 30           BA   26  Female           7  Your parents
# 29           BA   32  Female         5.5           You
# 37          MBA   27    Male           6           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 56                     Rarely       SV       10.5  3.50     Excellent
# 71                     Rarely       SE       11.0  2.70          Fair
# 30                 Frequently       SE       13.0  3.68     Excellent
# 29                 Frequently       SE       14.0  3.20     Excellent
# 37                     Rarely       SE       11.0  3.30     Excellent
#
#     Attendance       Study       Work  Working hours per week  \
# 56         0.9  Frequently  Full time                    48.0
# 71         0.9  Frequently  Full time                    40.0
# ...

# %%
pt.sort_values(by="Study",ascending=False).head()
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 57           BA   20    Male           8  Your parents
# 67          MBA   30    Male           4           You
# 66           BA   24    Male           6           You
# 63           BA   22  Female           6           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 57                     Rarely       SE       13.0  3.00          Fair
# 67                 Frequently       SE       16.0  3.00     Excellent
# 66                 Frequently       SV       16.0  2.60     Excellent
# 63                     Rarely       SE       14.0  3.40     Excellent
#
#     Attendance          Study       Work  Working hours per week  \
# 0          1.0  Prior to exam         No                     0.0
# 57         0.9  Prior to exam         No                     0.0
# ...

# %%
pt.sort_values(by="Degree Level",ascending=False).loc[57]
# Out:
# Degree Level                             BA
# Age                                      20
# Gender                                 Male
# Hours_sleep                               8
# Fees                           Your parents
# Extracurricular activities           Rarely
# Bac_type                                 SE
# Bac_grade                              13.0
# GPA                                     3.0
# English_level                          Fair
# Attendance                              0.9
# Study                         Prior to exam
# Work                                     No
# Working hours per week                  0.0
# Work_study_related                      NaN
# Higher_Diploma                           No
# SUM                                    23.0
# sum2                                 292.15
# Average                            3.043229
# Name: 57, dtype: object

# %%
pt.sort_values(by="English_level",ascending=False).loc[63]
# Out:
# Degree Level                             BA
# Age                                      22
# Gender                               Female
# Hours_sleep                               6
# Fees                                    You
# Extracurricular activities           Rarely
# Bac_type                                 SE
# Bac_grade                              14.0
# GPA                                     3.4
# English_level                     Excellent
# Attendance                              0.8
# Study                         Prior to exam
# Work                              Full time
# Working hours per week                 35.0
# Work_study_related                      Yes
# Higher_Diploma                          Yes
# SUM                                    25.4
# sum2                                 292.15
# Average                            3.043229
# Name: 63, dtype: object

# %%
pt[['Age','Gender']].sort_values(by='Gender',ascending=True)
# Out:
#     Age  Gender
# 0    25  Female
# 36   23  Female
# 42   23  Female
# 43   31  Female
# 44   31  Female
# ..  ...     ...
# 59   24    Male
# 60   22    Male
# 19   27    Male
# 66   24    Male
# 95   22    Male
#
# [96 rows x 2 columns]

# %%
pt[['Age','Gender']].sort_values(by='Gender',ascending=False)
# Out:
#     Age  Gender
# 48   28    Male
# 50   26    Male
# 57   20    Male
# 56   27    Male
# 55   27    Male
# ..  ...     ...
# 62   23  Female
# 63   22  Female
# 64   23  Female
# 36   23  Female
# 0    25  Female
#
# [96 rows x 2 columns]

# %%
pt[['Age','Gender','Bac_grade']].sort_values(by='Gender',ascending=False)
# Out:
#     Age  Gender  Bac_grade
# 48   28    Male       10.0
# 50   26    Male       13.0
# 57   20    Male       13.0
# 56   27    Male       10.5
# 55   27    Male       11.0
# ..  ...     ...        ...
# 62   23  Female       12.0
# 63   22  Female       14.0
# 64   23  Female       14.0
# 36   23  Female       14.0
# 0    25  Female       12.0
#
# [96 rows x 3 columns]

# %%
pt[['Age','Gender','Bac_grade']].sort_values(by='Gender',ascending=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
pt[['Age','Gender','Bac_grade']].sort_values(by='Gender',ascending=False).head(8).plot(kind='bar')
# Out:
# <Axes: >

# %%
pt[['Age','Gender','Bac_grade']].sort_values(by='Age',ascending=False).head(8).plot(kind='bar')
# Out:
# <Axes: >

# %%
pt[['Age','Gender','Bac_grade']].sort_values(by='Bac_grade',ascending=False).head(8).plot(kind='bar')
# Out:
# <Axes: >

# %%
pt[['Age','Gender']].head(8)
# Out:
#    Age  Gender
# 0   25  Female
# 1   23  Female
# 2   21  Female
# 3   19  Female
# 4   20  Female
# 5   21    Male
# 6   18    Male
# 7   21  Female

# %%
pt[['Age','Gender']].tail(8)
# Out:
#     Age  Gender
# 88   24  Female
# 89   24    Male
# 90   29    Male
# 91   23    Male
# 92   25    Male
# 93   26  Female
# 94   27    Male
# 95   22    Male

# %% [markdown]
# ### Concantenate

# %%
mn=pt[['Age','Gender']].head(8)

# %%
mn
# Out:
#    Age  Gender
# 0   25  Female
# 1   23  Female
# 2   21  Female
# 3   19  Female
# 4   20  Female
# 5   21    Male
# 6   18    Male
# 7   21  Female

# %%
nm=pt[['Age','Gender']].tail(8)

# %%
nm
# Out:
#     Age  Gender
# 88   24  Female
# 89   24    Male
# 90   29    Male
# 91   23    Male
# 92   25    Male
# 93   26  Female
# 94   27    Male
# 95   22    Male

# %%
pd.concat([mn,nm],axis =1) #arrange side by side
# Out:
#      Age  Gender   Age  Gender
# 0   25.0  Female   NaN     NaN
# 1   23.0  Female   NaN     NaN
# 2   21.0  Female   NaN     NaN
# 3   19.0  Female   NaN     NaN
# 4   20.0  Female   NaN     NaN
# 5   21.0    Male   NaN     NaN
# 6   18.0    Male   NaN     NaN
# 7   21.0  Female   NaN     NaN
# 88   NaN     NaN  24.0  Female
# 89   NaN     NaN  24.0    Male
# 90   NaN     NaN  29.0    Male
# 91   NaN     NaN  23.0    Male
# 92   NaN     NaN  25.0    Male
# 93   NaN     NaN  26.0  Female
# 94   NaN     NaN  27.0    Male
# 95   NaN     NaN  22.0    Male

# %%
pd.concat([mn,nm],axis =0) #arrange on top of each other
# Out:
#     Age  Gender
# 0    25  Female
# 1    23  Female
# 2    21  Female
# 3    19  Female
# 4    20  Female
# 5    21    Male
# 6    18    Male
# 7    21  Female
# 88   24  Female
# 89   24    Male
# 90   29    Male
# 91   23    Male
# 92   25    Male
# 93   26  Female
# 94   27    Male
# 95   22    Male

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %% [markdown]
# ### Pivot Tables

# %%
pt.pivot_table(pt,index=["Gender","Degree Level"])
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9052\3204959700.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pt.pivot_table(pt,index=["Gender","Degree Level"])
#                            Age  Attendance   Average  Bac_grade       GPA  \
# Gender Degree Level
# Female BA            23.200000    0.810000  3.043229  12.702000  3.066286
#        MBA           24.571429    0.807143  3.043229  12.071429  3.022143
# Male   BA            24.677419    0.751613  3.043229  11.985484  2.938065
#        MBA           27.062500    0.837500  3.043229  12.012500  3.215000
#
#                            SUM  Working hours per week    sum2
# Gender Degree Level
# Female BA            26.266286               36.714286  292.15
#        MBA           27.593571               40.214286  292.15
# ...

# %%
pt.pivot_table(pt,index=["Gender","Degree Level"]).plot(kind='bar')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9052\3666850779.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pt.pivot_table(pt,index=["Gender","Degree Level"]).plot(kind='bar')
# <Axes: xlabel='Gender,Degree Level'>

# %%
pt.corr()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9052\188322357.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pt.corr()
#                              Age  Bac_grade       GPA  Attendance  \
# Age                     1.000000  -0.006983  0.000698    0.030437
# Bac_grade              -0.006983   1.000000  0.410143    0.144180
# GPA                     0.000698   0.410143  1.000000    0.401625
# Attendance              0.030437   0.144180  0.401625    1.000000
# Working hours per week  0.239547  -0.102368 -0.186132   -0.167822
# SUM                     0.986123   0.061206  0.166707    0.096689
# sum2                         NaN        NaN       NaN         NaN
# Average                      NaN        NaN       NaN         NaN
#
#                         Working hours per week       SUM  sum2  Average
# ...

# %%
pt['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
pt['Gender'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Gender'>

# %%
pt['Gender'].drop_duplicates().count()
# Out:
# 2

# %% [markdown]
# ### The Bookworms are those students who RARELY engage in EXTRACURRICULAR ACTIVITIES and STUDY Frequently, how many bookworms are there in the data?

# %%
pt.columns
# Out:
# Index(['Degree Level', 'Age', 'Gender', 'Hours_sleep', 'Fees',
#        'Extracurricular activities', 'Bac_type', 'Bac_grade', 'GPA',
#        'English_level', 'Attendance', 'Study', 'Work',
#        'Working hours per week', 'Work_study_related', 'Higher_Diploma', 'SUM',
#        'sum2', 'Average'],
#       dtype='object')

# %%
# pt.query('Extracurricular activities=="Rarely" & Study=="Frequently"')


pt[ (pt['Extracurricular activities']=='Rarely') & 
   (pt['Study']=='Frequently')].shape
# Out:
# (14, 19)

# %%
there are 14 bookworms in the data
