# %%
import pandas as pd

# %%
pd.read_excel(r'C:\Users\PC\Desktop\Phython Data Analysis\Python Data Analysis\Academic Success Dataset.xlsx')
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt=pd.read_excel(r'C:\Users\PC\Desktop\Phython Data Analysis\Python Data Analysis\Academic Success Dataset.xlsx')

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt.shape
# Out:
# (96, 16)

# %%
pt.info
# Out:
# <bound method DataFrame.info of    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# ...

# %%
pt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Degree Level                96 non-null     object
#  1   Age                         96 non-null     int64
#  2   Gender                      96 non-null     object
#  3   Hours_sleep                 96 non-null     object
#  4   Fees                        96 non-null     object
#  5   Extracurricular activities  96 non-null     object
#  6   Bac_type                    96 non-null     object
#  7   Bac_grade                   96 non-null     float64
#  8   GPA                         96 non-null     float64
#  9   English_level               96 non-null     object
#  10  Attendance                  96 non-null     float64
#  11  Study                       96 non-null     object
#  12  Work                        96 non-null     object
# ...

# %%
pt.describe()
# Out:
#              Age  Bac_grade        GPA  Attendance  Working hours per week
# count  96.000000  96.000000  96.000000   96.000000               96.000000
# mean   24.520833  12.263750   3.043229    0.795312               38.671875
# std     3.118634   1.598609   0.525099    0.170151               14.265126
# min    18.000000  10.000000   1.500000    0.300000                0.000000
# 25%    22.000000  11.000000   2.700000    0.700000               30.000000
# 50%    24.500000  12.000000   3.000000    0.850000               40.000000
# 75%    27.000000  13.000000   3.400000    0.900000               48.000000
# max    32.000000  18.000000   4.000000    1.000000               60.000000

# %%
pt.isnull()
# Out:
#     Degree Level    Age  Gender  Hours_sleep   Fees  \
# 0          False  False   False        False  False
# 1          False  False   False        False  False
# 2          False  False   False        False  False
# 3          False  False   False        False  False
# 4          False  False   False        False  False
# ..           ...    ...     ...          ...    ...
# 91         False  False   False        False  False
# 92         False  False   False        False  False
# 93         False  False   False        False  False
# 94         False  False   False        False  False
# 95         False  False   False        False  False
#
#     Extracurricular activities  Bac_type  Bac_grade    GPA  English_level  \
# 0                        False     False      False  False          False
# 1                        False     False      False  False          False
# 2                        False     False      False  False          False
# ...

# %%
pt.isnull
# Out:
# <bound method DataFrame.isnull of    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# ...

# %%
pt.isnull().sum()
# Out:
# Degree Level                  0
# Age                           0
# Gender                        0
# Hours_sleep                   0
# Fees                          0
# Extracurricular activities    0
# Bac_type                      0
# Bac_grade                     0
# GPA                           0
# English_level                 0
# Attendance                    0
# Study                         0
# Work                          0
# Working hours per week        0
# Work_study_related            6
# Higher_Diploma                0
# dtype: int64

# %%
pt.notnull().sum()
# Out:
# Degree Level                  96
# Age                           96
# Gender                        96
# Hours_sleep                   96
# Fees                          96
# Extracurricular activities    96
# Bac_type                      96
# Bac_grade                     96
# GPA                           96
# English_level                 96
# Attendance                    96
# Study                         96
# Work                          96
# Working hours per week        96
# Work_study_related            90
# Higher_Diploma                96
# dtype: int64

# %%
pt.duplicated().sum()
# Out:
# 1

# %%
pt.isna().sum()
# Out:
# Degree Level                  0
# Age                           0
# Gender                        0
# Hours_sleep                   0
# Fees                          0
# Extracurricular activities    0
# Bac_type                      0
# Bac_grade                     0
# GPA                           0
# English_level                 0
# Attendance                    0
# Study                         0
# Work                          0
# Working hours per week        0
# Work_study_related            6
# Higher_Diploma                0
# dtype: int64

# %%
pt.notna().sum()
# Out:
# Degree Level                  96
# Age                           96
# Gender                        96
# Hours_sleep                   96
# Fees                          96
# Extracurricular activities    96
# Bac_type                      96
# Bac_grade                     96
# GPA                           96
# English_level                 96
# Attendance                    96
# Study                         96
# Work                          96
# Working hours per week        96
# Work_study_related            90
# Higher_Diploma                96
# dtype: int64

# %%
pt.duplicated() #
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 91    False
# 92    False
# 93    False
# 94    False
# 95    False
# Length: 96, dtype: bool

# %% [markdown]
# ## pt.drop_duplcates(inplace=True) #affects the original data
# #pt.drop_duplcates(subset='paying customer') #dropping duplicates specified columns

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt.drop_duplicates()
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt.drop_duplicates(inplace=True)

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt.drop_duplicates(subset='Extracurricular activities') #Please can u explain more on dropping dupplicates
# Out:
#   Degree Level  Age  Gender Hours_sleep          Fees  \
# 0           BA   25  Female           6  Your parents
# 4           BA   20  Female           6  Your parents
# 5           BA   21    Male           4           You
#
#   Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                     Rarely       SV       12.0  3.23     Excellent
# 4                 Frequently       SE       14.0  3.40     Excellent
# 5                      Never       SV       12.5  3.50     Excellent
#
#    Attendance          Study       Work  Working hours per week  \
# 0         1.0  Prior to exam         No                     0.0
# 4         0.9     Frequently  Part Time                    18.0
# 5         0.5  Prior to exam  Full time                    40.0
#
#   Work_study_related Higher_Diploma
# 0                NaN            Yes
# 4                 No            Yes
# 5                Yes            Yes

# %%
pt.drop_duplicates(subset='English_level')
# Out:
#   Degree Level  Age  Gender Hours_sleep          Fees  \
# 0           BA   25  Female           6  Your parents
# 1          MBA   23  Female           6           You
# 3           BA   19  Female           6           You
#
#   Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                     Rarely       SV       12.0  3.23     Excellent
# 1                     Rarely       SE       13.0  2.40          Fair
# 3                     Rarely       SE       12.7  2.70          Poor
#
#    Attendance          Study       Work  Working hours per week  \
# 0         1.0  Prior to exam         No                     0.0
# 1         0.4  Prior to exam  Full time                    45.0
# 3         0.6  Prior to exam  Full time                    48.0
#
#   Work_study_related Higher_Diploma
# 0                NaN            Yes
# 1                 No             No
# 3                 No             No

# %%
pt.drop(columns='Fees') #dropping a single columns
# Out:
#    Degree Level  Age  Gender Hours_sleep Extracurricular activities Bac_type  \
# 0            BA   25  Female           6                     Rarely       SV
# 1           MBA   23  Female           6                     Rarely       SE
# 2            BA   21  Female           5                     Rarely       SE
# 3            BA   19  Female           6                     Rarely       SE
# 4            BA   20  Female           6                 Frequently       SE
# ..          ...  ...     ...         ...                        ...      ...
# 91           BA   23    Male           8                     Rarely       SE
# 92           BA   25    Male           9                     Rarely       BT
# 93           BA   26  Female           8                     Rarely       SE
# 94          MBA   27    Male           6                 Frequently       SE
# 95           BA   22    Male           4                 Frequently       SV
#
# ...

# %%
pt.drop(index=[1,3,5,7,8,12,15]) #dropping multiple index N.B the selected index will be dropped
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 2            BA   21  Female           5           You
# 4            BA   20  Female           6  Your parents
# 6            BA   18    Male           9           You
# 9           MBA   23  Female           8           You
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 2                      Rarely       SE       18.0  4.00     Excellent
# 4                  Frequently       SE       14.0  3.40     Excellent
# ...

# %%
pt.drop(index=[5,9,14,20,25,30,40,80])
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt.drop(columns=['Gender','Study']) #dropping multiple columns
# Out:
#    Degree Level  Age Hours_sleep          Fees Extracurricular activities  \
# 0            BA   25           6  Your parents                     Rarely
# 1           MBA   23           6           You                     Rarely
# 2            BA   21           5           You                     Rarely
# 3            BA   19           6           You                     Rarely
# 4            BA   20           6  Your parents                 Frequently
# ..          ...  ...         ...           ...                        ...
# 91           BA   23           8           You                     Rarely
# 92           BA   25           9           You                     Rarely
# 93           BA   26           8  Your parents                     Rarely
# 94          MBA   27           6           You                 Frequently
# 95           BA   22           4           You                 Frequently
#
#    Bac_type  Bac_grade   GPA English_level  Attendance       Work  \
# ...

# %%
pt.drop(columns=['Gender','Study','Higher_Diploma'])
# Out:
#    Degree Level  Age Hours_sleep          Fees Extracurricular activities  \
# 0            BA   25           6  Your parents                     Rarely
# 1           MBA   23           6           You                     Rarely
# 2            BA   21           5           You                     Rarely
# 3            BA   19           6           You                     Rarely
# 4            BA   20           6  Your parents                 Frequently
# ..          ...  ...         ...           ...                        ...
# 91           BA   23           8           You                     Rarely
# 92           BA   25           9           You                     Rarely
# 93           BA   26           8  Your parents                     Rarely
# 94          MBA   27           6           You                 Frequently
# 95           BA   22           4           You                 Frequently
#
#    Bac_type  Bac_grade   GPA English_level  Attendance       Work  \
# ...

# %% [markdown]
# ## CHANGING THE CASE IN A CATEGORICAL FEATURE (changing from small letter to capital and vice versa)

# %%
pt['Fees']=pt['Fees'].str.upper()

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 71           BA   25    MALE           5  your parents
# 72           BA   24  FEMALE           7  your parents
# 73           BA   21  FEMALE           7           you
# 74           BA   25  FEMALE           7           you
# 75           BA   26  FEMALE           7           you
# 76           BA   23  FEMALE           6           you
# 77           BA   27    MALE           6           you
# 78           BA   24    MALE           6           you
# 79           BA   25    MALE           7           you
# 80           BA   25  FEMALE           7           you
# 81           BA   27    MALE           6           you
# 82           BA   26    MALE           7           you
# 83           BA   26    MALE           6           you
# 84           BA   26  FEMALE           6           you
# 85          MBA   23  FEMALE           7           you
# 86           BA   23  FEMALE           7           you
# ...

# %%
pt['Fees']=pt['Fees'].str.lower()

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  your parents
# 1           MBA   23  Female           6           you
# 2            BA   21  Female           5           you
# 3            BA   19  Female           6           you
# 4            BA   20  Female           6  your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           you
# 92           BA   25    Male           9           you
# 93           BA   26  Female           8  your parents
# 94          MBA   27    Male           6           you
# 95           BA   22    Male           4           you
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt['Gender']=pt['Gender'].str.upper()

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  FEMALE           6  your parents
# 1           MBA   23  FEMALE           6           you
# 2            BA   21  FEMALE           5           you
# 3            BA   19  FEMALE           6           you
# 4            BA   20  FEMALE           6  your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    MALE           8           you
# 92           BA   25    MALE           9           you
# 93           BA   26  FEMALE           8  your parents
# 94          MBA   27    MALE           6           you
# 95           BA   22    MALE           4           you
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %% [markdown]
# ### L STRIP AND R STRIP METHOD

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 71           BA   25    MALE           5  your parents
# 72           BA   24  FEMALE           7  your parents
# 73           BA   21  FEMALE           7           you
# 74           BA   25  FEMALE           7           you
# 75           BA   26  FEMALE           7           you
# 76           BA   23  FEMALE           6           you
# 77           BA   27    MALE           6           you
# 78           BA   24    MALE           6           you
# 79           BA   25    MALE           7           you
# 80           BA   25  FEMALE           7           you
# 81           BA   27    MALE           6           you
# 82           BA   26    MALE           7           you
# 83           BA   26    MALE           6           you
# 84           BA   26  FEMALE           6           you
# 85          MBA   23  FEMALE           7           you
# 86           BA   23  FEMALE           7           you
# ...

# %%
pt.tail(10)
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 86           BA   23  FEMALE           7           you
# 87           BA   19    MALE         //6           you
# 88           BA   24  FEMALE           6  your parents
# 89          MBA   24    MALE           8  your parents
# 90           BA   29    MALE           6           you
# 91           BA   23    MALE           8           you
# 92           BA   25    MALE           9           you
# 93           BA   26  FEMALE           8  your parents
# 94          MBA   27    MALE           6           you
# 95           BA   22    MALE           4           you
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 86                     Rarely       SE       13.0  3.20          Fair
# 87                 Frequently       BT       13.0  2.80     Excellent
# 88                     Rarely       SE       12.0  3.00          Fair
# 89                     Rarely       SE       11.1  3.00          Fair
# ...

# %%
pt=pt.head(20)

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 71           BA   25    MALE           5  your parents
# 72           BA   24  FEMALE           7  your parents
# 73           BA   21  FEMALE           7           you
# 74           BA   25  FEMALE           7           you
# 75           BA   26  FEMALE           7           you
# 76           BA   23  FEMALE           6           you
# 77           BA   27    MALE           6           you
# 78           BA   24    MALE           6           you
# 79           BA   25    MALE           7           you
# 80           BA   25  FEMALE           7           you
# 81           BA   27    MALE           6           you
# 82           BA   26    MALE           7           you
# 83           BA   26    MALE           6           you
# 84           BA   26  FEMALE           6           you
# 85          MBA   23  FEMALE           7           you
# 86           BA   23  FEMALE           7           you
# ...

# %%
pt=pt.tail(25) #How do we clean a single column and also how do we bring out the clean dataset

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 71           BA   25    MALE           5  your parents
# 72           BA   24  FEMALE           7  your parents
# 73           BA   21  FEMALE           7           you
# 74           BA   25  FEMALE           7           you
# 75           BA   26  FEMALE           7           you
# 76           BA   23  FEMALE           6           you
# 77           BA   27    MALE           6           you
# 78           BA   24    MALE           6           you
# 79           BA   25    MALE           7           you
# 80           BA   25  FEMALE           7           you
# 81           BA   27    MALE           6           you
# 82           BA   26    MALE           7           you
# 83           BA   26    MALE           6           you
# 84           BA   26  FEMALE           6           you
# 85          MBA   23  FEMALE           7           you
# 86           BA   23  FEMALE           7           you
# ...

# %%
pt['Hours_sleep'].str.lstrip('//')
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#      ...
# 91    NaN
# 92    NaN
# 93    NaN
# 94    NaN
# 95    NaN
# Name: Hours_sleep, Length: 95, dtype: object

# %% [markdown]
# ## REPLACE METHOD

# %%
pt['Work_study_related'].str.replace('NaN','') #not affecting the NaN
# Out:
# 0     NaN
# 1      No
# 2     Yes
# 3      No
# 4      No
#      ...
# 91     No
# 92    Yes
# 93    Yes
# 94    Yes
# 95    Yes
# Name: Work_study_related, Length: 96, dtype: object

# %%
pt['Work_study_related'].str.replace('NaN','^')
# Out:
# 0     NaN
# 1      No
# 2     Yes
# 3      No
# 4      No
#      ...
# 91     No
# 92    Yes
# 93    Yes
# 94    Yes
# 95    Yes
# Name: Work_study_related, Length: 96, dtype: object

# %%
import pandas as pd

# %%
pd.read_excel(r'C:\Users\PC\Desktop\Phython Data Analysis\Python Data Analysis\Academic Success Dataset.xlsx')
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt=pd.read_excel(r'C:\Users\PC\Desktop\Phython Data Analysis\Python Data Analysis\Academic Success Dataset.xlsx')

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %%
pt['Work_study_related']=pt['Work_study_related'].str.replace('NaN','Y') #NaN not changing

# %%
pt
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...
